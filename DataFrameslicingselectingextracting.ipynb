# %%
import pandas as pd
import numpy as np

# %%
mydata=pd.read_excel(r"C:/Users/SHUBH_RAM/Desktop/Tool_PPT/Ml_Data/mp_up_data/mp_16.xlsx")

# %%
mydata.head()
# Out:
#     ID               MP Name Nature of membership         Start of Term  \
# 0  852       Ajay Misra Teni              Elected  Sunday, May 18, 2014
# 1  855          Akshay Yadav              Elected  Sunday, May 18, 2014
# 2  865             Anju Bala              Elected  Sunday, May 18, 2014
# 3  867          Anshul Verma              Elected  Sunday, May 18, 2014
# 4  870  Anupriya Singh Patel              Elected  Sunday, May 18, 2014
#
#   End of Term Number of terms Constituency          State  \
# 0   In office           First        Kheri  Uttar Pradesh
# 1   In office           First    Firozabad  Uttar Pradesh
# 2   In office           First      Misrikh  Uttar Pradesh
# 3   In office           First       Hardoi  Uttar Pradesh
# 4   In office           First     Mirzapur  Uttar Pradesh
#
#           Political party  Gender    ...     National Debates average  \
# 0  Bharatiya Janata Party    Male    ...                         67.1
# ...

# %%
#Total Row and column
mydata.shape
# Out:
# (82, 28)

# %% [markdown]
# #### extract a column using square brackets []

# %%
mydata["Constituency"][:5]
# Out:
# 0        Kheri
# 1    Firozabad
# 2      Misrikh
# 3       Hardoi
# 4     Mirzapur
# Name: Constituency, dtype: object

# %%
mydata[["Constituency","State"]][:5]
# Out:
#   Constituency          State
# 0        Kheri  Uttar Pradesh
# 1    Firozabad  Uttar Pradesh
# 2      Misrikh  Uttar Pradesh
# 3       Hardoi  Uttar Pradesh
# 4     Mirzapur  Uttar Pradesh

# %% [markdown]
# ##### Selecting pandas data using “loc”

# %%
#Select two rows and three columns
mydata.loc[["R1","R2"],["c1","c2","C3"]]

# %%
#Selecting all of the rows and some columns and display top 10 samples
mydata.loc[:, ["Constituency","State"]][:10]
# Out:
#      Constituency          State
# 0           Kheri  Uttar Pradesh
# 1       Firozabad  Uttar Pradesh
# 2         Misrikh  Uttar Pradesh
# 3          Hardoi  Uttar Pradesh
# 4        Mirzapur  Uttar Pradesh
# 5          Etawah  Uttar Pradesh
# 6  Fatehpur Sikri  Uttar Pradesh
# 7         Kairana  Uttar Pradesh
# 8           Banda  Uttar Pradesh
# 9          Jalaun  Uttar Pradesh

# %%
#Selecting a single row with .iloc
mydata.iloc[0]
# Out:
# ID                                                                                     852
# MP Name                                                                    Ajay Misra Teni
# Nature of membership                                                               Elected
# Start of Term                                                         Sunday, May 18, 2014
# End of Term                                                                      In office
# Number of terms                                                                      First
# Constituency                                                                         Kheri
# State                                                                        Uttar Pradesh
# Political party                                                     Bharatiya Janata Party
# Gender                                                                                Male
# ...

# %%
#Selecting multiple rows with .iloc
mydata.iloc[[0,3,4]]
# Out:
#     ID               MP Name Nature of membership         Start of Term  \
# 0  852       Ajay Misra Teni              Elected  Sunday, May 18, 2014
# 3  867          Anshul Verma              Elected  Sunday, May 18, 2014
# 4  870  Anupriya Singh Patel              Elected  Sunday, May 18, 2014
#
#   End of Term Number of terms Constituency          State  \
# 0   In office           First        Kheri  Uttar Pradesh
# 3   In office           First       Hardoi  Uttar Pradesh
# 4   In office           First     Mirzapur  Uttar Pradesh
#
#           Political party  Gender    ...     National Debates average  \
# 0  Bharatiya Janata Party    Male    ...                         67.1
# 3  Bharatiya Janata Party    Male    ...                         67.1
# 4                Apna Dal  Female    ...                         35.4
#
#   National Private Member Bills average  National Questions average  \
# 0                                   2.3                       292.0
# ...

# %%
mydata.iloc[0:4]
# Out:
#     ID          MP Name Nature of membership         Start of Term  \
# 0  852  Ajay Misra Teni              Elected  Sunday, May 18, 2014
# 1  855     Akshay Yadav              Elected  Sunday, May 18, 2014
# 2  865        Anju Bala              Elected  Sunday, May 18, 2014
# 3  867     Anshul Verma              Elected  Sunday, May 18, 2014
#
#   End of Term Number of terms Constituency          State  \
# 0   In office           First        Kheri  Uttar Pradesh
# 1   In office           First    Firozabad  Uttar Pradesh
# 2   In office           First      Misrikh  Uttar Pradesh
# 3   In office           First       Hardoi  Uttar Pradesh
#
#           Political party  Gender    ...     National Debates average  \
# 0  Bharatiya Janata Party    Male    ...                         67.1
# 1         Samajwadi Party    Male    ...                         67.1
# 2  Bharatiya Janata Party  Female    ...                         67.1
# ...

# %%
#Some useful extracting using slice operator [:]
#mydata.iloc[8:]
#mydata.iloc[::3]

# %%
#Selecting rows and columns simultaneously 
mydata.iloc[[0,3,4],[0,4,5]]
# Out:
#     ID End of Term Number of terms
# 0  852   In office           First
# 3  867   In office           First
# 4  870   In office           First
